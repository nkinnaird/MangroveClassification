# %%
# import keras
# from keras.utils import plot_model
# import pydot as pyd
# import tensorflow as tf
# # from tensorflow import keras
# from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
# # import pydotplus
# # import keras.utils.vis_utils
# from keras.utils.vis_utils import model_to_dot
# keras.utils.vis_utils.pydot = pyd
# # from importlib import reload
# # reload(keras.utils.vis_utils)

# %%
import keras
import pydot as pyd
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

keras.utils.vis_utils.pydot = pyd

# %%
model = keras.Sequential()
model.add(keras.layers.Conv2D(32, kernel_size=3, padding='valid', activation='relu', input_shape=(7, 7, 7)))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Conv2D(48, kernel_size=3, padding='valid', activation='relu'))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Dense(2, activation='softmax'))

# %%
dot_img_file = 'SavedPlots/CNN_model_architecture.png'
keras.utils.vis_utils.plot_model(model, to_file=dot_img_file, show_shapes=True)

# %%
# def visualize_model(model):
#   return SVG(model_to_dot(model).create(prog='dot', format='svg'))
# #create your model
# #then call the function on your model
# visualize_model(model)
